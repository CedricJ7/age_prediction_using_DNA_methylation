# %% [markdown]
# # Analyse Exploratoire des Données de Méthylation ADN
#
# Exploration des niveaux de méthylation en fonction de l'âge et du sexe :
# 1. Moyenne et variance des niveaux de méthylation par âge et sexe
# 2. Distribution des niveaux de méthylation par âge et sexe
# 3. Distribution des corrélations avec l'âge, comparaison par sexe
# 4. Réduction de dimension (PCA, t-SNE, UMAP) pour visualiser les patterns liés à l'âge et au sexe

# %%
import warnings
warnings.filterwarnings('ignore')

import numpy as np
import pandas as pd
from pathlib import Path
from time import time

from sklearn.decomposition import PCA
from sklearn.manifold import TSNE

try:
    import umap
    HAS_UMAP = True
except ImportError:
    HAS_UMAP = False
    print('UMAP non disponible, sera ignoré.')

import matplotlib.pyplot as plt
import seaborn as sns

RANDOM_STATE = 42
np.random.seed(RANDOM_STATE)

DATA_DIR = Path('Data')
CHUNK_SIZE = 5000
TOP_K = 500

print('Imports OK')
# Out:
# UMAP non disponible, sera ignoré.
# Imports OK

# %% [markdown]
# ## Chargement des Données
#
# Les données de méthylation (894K CpG x 400 échantillons) sont trop volumineuses pour être chargées en mémoire.
# On calcule les statistiques par chunks et on charge uniquement les top-500 CpG pour les analyses détaillées.

# %%
# --- Annotations ---
ind = pd.read_csv(DATA_DIR / 'annot_projet.csv')
ind = ind.dropna(subset=['age', 'Sample_description']).copy()
ind['Sample_description'] = ind['Sample_description'].astype(str)
ind['sexe'] = ind['female'].apply(lambda x: 'F' if str(x).upper() == 'TRUE' else 'M')
ind['age_group'] = pd.cut(ind['age'], bins=[0, 30, 50, 70, 100], labels=['<30', '30-50', '50-70', '>70'])
ind = ind.set_index('Sample_description')

# --- Identifier les échantillons communs ---
data_path = DATA_DIR / 'complete_impute_cpg.csv'
sample_header = pd.read_csv(data_path, nrows=0)
all_sample_ids = list(sample_header.columns)
common_ids = [s for s in all_sample_ids if s in ind.index]

print(f'Échantillons : {len(common_ids)}')
print(f"Âge : {ind.loc[common_ids, 'age'].mean():.1f} ± {ind.loc[common_ids, 'age'].std():.1f} ans")
print(f"  Range : {ind.loc[common_ids, 'age'].min():.1f} - {ind.loc[common_ids, 'age'].max():.1f}")
print(f"Sexe : {(ind.loc[common_ids, 'sexe'] == 'F').sum()} F, {(ind.loc[common_ids, 'sexe'] == 'M').sum()} M")
print(f"Groupes d'âge :")
print(ind.loc[common_ids, 'age_group'].value_counts().sort_index().to_string())
# Out:
# Échantillons : 400
# Âge : 53.0 ± 21.2 ans
#   Range : 18.1 - 90.0
# Sexe : 214 F, 186 M
# Groupes d'âge :
# age_group
# <30       77
# 30-50    110
# 50-70    101
# >70      112

# %% [markdown]
# ## 1. Moyenne et Variance des Niveaux de Méthylation par Âge et Sexe
#
# Calcul par chunks : pour chaque échantillon, on accumule la somme et somme des carrés de toutes les valeurs beta.

# %%
# --- Calculer mean/var par échantillon via chunks ---
print('Calcul des statistiques par échantillon (par chunks)...')
t0 = time()
n_cpg = 0
sample_sum = np.zeros(len(common_ids), dtype=np.float64)
sample_sum2 = np.zeros(len(common_ids), dtype=np.float64)

for chunk in pd.read_csv(data_path, usecols=common_ids, chunksize=CHUNK_SIZE):
    x = chunk.to_numpy(dtype=np.float64)
    sample_sum += np.nansum(x, axis=0)
    sample_sum2 += np.nansum(x**2, axis=0)
    n_cpg += len(chunk)

sample_mean = sample_sum / n_cpg
sample_var = sample_sum2 / n_cpg - sample_mean**2

print(f'  {n_cpg} CpG traités en {time()-t0:.1f}s')

# --- Construire DataFrame de résultats ---
stats_df = pd.DataFrame({
    'sample_id': common_ids,
    'mean_beta': sample_mean,
    'var_beta': sample_var,
    'age': ind.loc[common_ids, 'age'].values,
    'sexe': ind.loc[common_ids, 'sexe'].values,
    'age_group': ind.loc[common_ids, 'age_group'].values,
})

print(f'\nStatistiques par groupe :')
print(stats_df.groupby('sexe')[['mean_beta', 'var_beta']].agg(['mean', 'std']).round(6))
print()
print(stats_df.groupby('age_group')[['mean_beta', 'var_beta']].agg(['mean', 'std']).round(6))
# Out:
# Calcul des statistiques par échantillon (par chunks)...
#   894006 CpG traités en 16.5s
#
# Statistiques par groupe :
#      mean_beta            var_beta
#           mean       std      mean       std
# sexe
# F     0.628695  0.005347  0.127502  0.003931
# M     0.625921  0.012200  0.129613  0.004332
#
#           mean_beta            var_beta
#                mean       std      mean       std
# age_group
# <30        0.630297  0.009155  0.129168  0.003615
# 30-50      0.627851  0.013827  0.128032  0.003613
# 50-70      0.627373  0.004110  0.127617  0.003693
# >70        0.625009  0.006140  0.129237  0.005394

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# --- Mean beta vs Age, coloré par sexe ---
ax = axes[0, 0]
for sexe, color in [('F', '#e74c3c'), ('M', '#3498db')]:
    mask = stats_df['sexe'] == sexe
    ax.scatter(stats_df.loc[mask, 'age'], stats_df.loc[mask, 'mean_beta'],
               alpha=0.6, label=sexe, color=color, s=30)
ax.set_xlabel('Âge')
ax.set_ylabel('Moyenne beta (par échantillon)')
ax.set_title('Moyenne de méthylation vs Âge')
ax.legend()

# --- Variance beta vs Age ---
ax = axes[0, 1]
for sexe, color in [('F', '#e74c3c'), ('M', '#3498db')]:
    mask = stats_df['sexe'] == sexe
    ax.scatter(stats_df.loc[mask, 'age'], stats_df.loc[mask, 'var_beta'],
               alpha=0.6, label=sexe, color=color, s=30)
ax.set_xlabel('Âge')
ax.set_ylabel('Variance beta (par échantillon)')
ax.set_title('Variance de méthylation vs Âge')
ax.legend()

# --- Boxplot mean beta par age_group et sexe ---
ax = axes[1, 0]
sns.boxplot(data=stats_df, x='age_group', y='mean_beta', hue='sexe',
            palette={'F': '#e74c3c', 'M': '#3498db'}, ax=ax)
ax.set_xlabel("Groupe d'âge")
ax.set_ylabel('Moyenne beta')
ax.set_title("Moyenne de méthylation par groupe d'âge et sexe")

# --- Boxplot variance par age_group et sexe ---
ax = axes[1, 1]
sns.boxplot(data=stats_df, x='age_group', y='var_beta', hue='sexe',
            palette={'F': '#e74c3c', 'M': '#3498db'}, ax=ax)
ax.set_xlabel("Groupe d'âge")
ax.set_ylabel('Variance beta')
ax.set_title("Variance de méthylation par groupe d'âge et sexe")

plt.tight_layout()
plt.savefig('results/eda_mean_var_by_age_sex.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 2. Distribution des Niveaux de Méthylation par Âge et Sexe
#
# Distribution globale des valeurs beta et distribution par sous-groupe.

# %%
# --- Histogramme des valeurs beta (échantillon de CpG pour mémoire) ---
print('Chargement d\'un échantillon de CpG pour les distributions...')
# Prendre 10000 CpG au hasard
np.random.seed(RANDOM_STATE)
sample_cpg_idx = np.sort(np.random.choice(n_cpg, size=10000, replace=False))

rows = []
start = 0
for chunk in pd.read_csv(data_path, usecols=common_ids, chunksize=CHUNK_SIZE):
    end = start + len(chunk)
    pos_s = np.searchsorted(sample_cpg_idx, start)
    pos_e = np.searchsorted(sample_cpg_idx, end)
    local = sample_cpg_idx[pos_s:pos_e] - start
    if len(local) > 0:
        rows.append(chunk.iloc[local].values)
    start = end

X_sample = np.vstack(rows).T.astype(np.float32)  # (400, 10000)
print(f'  Échantillon chargé : {X_sample.shape}')

ages = ind.loc[common_ids, 'age'].values
sexes = ind.loc[common_ids, 'sexe'].values
age_groups = ind.loc[common_ids, 'age_group'].values
# Out:
# Chargement d'un échantillon de CpG pour les distributions...
#   Échantillon chargé : (400, 10000)

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# --- Distribution globale ---
ax = axes[0]
ax.hist(X_sample.flatten(), bins=100, density=True, alpha=0.7, color='steelblue', edgecolor='white')
ax.set_xlabel('Valeur beta')
ax.set_ylabel('Densité')
ax.set_title('Distribution globale des valeurs beta\n(échantillon 10K CpG)')

# --- Distribution par sexe (mean beta par échantillon) ---
ax = axes[1]
for sexe, color in [('F', '#e74c3c'), ('M', '#3498db')]:
    mask = sexes == sexe
    means = X_sample[mask].mean(axis=1)
    ax.hist(means, bins=25, density=True, alpha=0.6, label=sexe, color=color, edgecolor='white')
ax.set_xlabel('Moyenne beta par échantillon')
ax.set_ylabel('Densité')
ax.set_title('Distribution de la moyenne beta par sexe')
ax.legend()

# --- Violin plot par groupe d'âge ---
ax = axes[2]
data_violin = []
for ag in ['<30', '30-50', '50-70', '>70']:
    mask = age_groups == ag
    data_violin.append(X_sample[mask].mean(axis=1))
parts = ax.violinplot(data_violin, positions=range(4), showmeans=True, showmedians=True)
ax.set_xticks(range(4))
ax.set_xticklabels(['<30', '30-50', '50-70', '>70'])
ax.set_xlabel("Groupe d'âge")
ax.set_ylabel('Moyenne beta par échantillon')
ax.set_title("Distribution par groupe d'âge")

plt.tight_layout()
plt.savefig('results/eda_beta_distributions.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 3. Distribution des Corrélations avec l'Âge par Sexe
#
# On calcule la corrélation de chaque CpG avec l'âge, globalement et séparément par sexe.

# %%
# --- Corrélations globales et par sexe (par chunks) ---
print('Calcul des corrélations CpG-âge par chunks...')
t0 = time()

y_all = ind.loc[common_ids, 'age'].values.astype(np.float32)
sexe_arr = ind.loc[common_ids, 'sexe'].values
mask_f = sexe_arr == 'F'
mask_m = sexe_arr == 'M'

y_all_c = y_all - y_all.mean()
y_all_den = np.sqrt(np.sum(y_all_c**2))
y_f = y_all[mask_f]
y_f_c = y_f - y_f.mean()
y_f_den = np.sqrt(np.sum(y_f_c**2))
y_m = y_all[mask_m]
y_m_c = y_m - y_m.mean()
y_m_den = np.sqrt(np.sum(y_m_c**2))

corrs_all = []
corrs_f = []
corrs_m = []

for chunk in pd.read_csv(data_path, usecols=common_ids, chunksize=CHUNK_SIZE):
    x = chunk.to_numpy(dtype=np.float32)
    if np.isnan(x).any():
        row_means = np.nanmean(x, axis=1, keepdims=True)
        row_means = np.where(np.isnan(row_means), 0, row_means)
        x = np.where(np.isnan(x), row_means, x)
    
    # Global
    x_c = x - x.mean(axis=1, keepdims=True)
    num = x_c @ y_all_c
    den = np.sqrt(np.sum(x_c**2, axis=1)) * y_all_den
    corrs_all.append(np.divide(num, den, out=np.zeros_like(num), where=den != 0))
    
    # Femmes
    xf = x[:, mask_f]
    xf_c = xf - xf.mean(axis=1, keepdims=True)
    num_f = xf_c @ y_f_c
    den_f = np.sqrt(np.sum(xf_c**2, axis=1)) * y_f_den
    corrs_f.append(np.divide(num_f, den_f, out=np.zeros_like(num_f), where=den_f != 0))
    
    # Hommes
    xm = x[:, mask_m]
    xm_c = xm - xm.mean(axis=1, keepdims=True)
    num_m = xm_c @ y_m_c
    den_m = np.sqrt(np.sum(xm_c**2, axis=1)) * y_m_den
    corrs_m.append(np.divide(num_m, den_m, out=np.zeros_like(num_m), where=den_m != 0))

corrs_all = np.concatenate(corrs_all)
corrs_f = np.concatenate(corrs_f)
corrs_m = np.concatenate(corrs_m)

print(f'  Calculé en {time()-t0:.1f}s ({len(corrs_all)} CpG)')
print(f'  |corr| > 0.5 : {(np.abs(corrs_all) > 0.5).sum()} CpG')
print(f'  |corr| > 0.7 : {(np.abs(corrs_all) > 0.7).sum()} CpG')
print(f'  |corr| > 0.9 : {(np.abs(corrs_all) > 0.9).sum()} CpG')
# Out:
# Calcul des corrélations CpG-âge par chunks...
#   Calculé en 24.6s (894006 CpG)
#   |corr| > 0.5 : 4549 CpG
#   |corr| > 0.7 : 233 CpG
#   |corr| > 0.9 : 1 CpG

# %%
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# --- Distribution globale des corrélations ---
ax = axes[0]
ax.hist(corrs_all, bins=200, density=True, alpha=0.7, color='steelblue', edgecolor='none')
ax.set_xlabel('Corrélation avec l\'âge')
ax.set_ylabel('Densité')
ax.set_title('Distribution des corrélations CpG-âge\n(tous échantillons)')
ax.axvline(0, color='gray', linestyle='--', alpha=0.5)

# --- Comparaison F vs M ---
ax = axes[1]
ax.hist(corrs_f, bins=200, density=True, alpha=0.5, color='#e74c3c', label='Femmes', edgecolor='none')
ax.hist(corrs_m, bins=200, density=True, alpha=0.5, color='#3498db', label='Hommes', edgecolor='none')
ax.set_xlabel('Corrélation avec l\'âge')
ax.set_ylabel('Densité')
ax.set_title('Corrélations CpG-âge par sexe')
ax.legend()

# --- Scatter corr F vs corr M ---
ax = axes[2]
# Sous-échantillonner pour la visu
idx_sub = np.random.choice(len(corrs_all), size=min(50000, len(corrs_all)), replace=False)
ax.scatter(corrs_f[idx_sub], corrs_m[idx_sub], alpha=0.1, s=1, color='purple')
ax.plot([-1, 1], [-1, 1], 'r--', alpha=0.5)
ax.set_xlabel('Corrélation (Femmes)')
ax.set_ylabel('Corrélation (Hommes)')
ax.set_title('Corrélation F vs M par CpG')
ax.set_xlim(-1, 1)
ax.set_ylim(-1, 1)
ax.set_aspect('equal')

plt.tight_layout()
plt.savefig('results/eda_correlation_distributions.png', dpi=150, bbox_inches='tight')
plt.show()

# Corrélation entre les corrélations F et M
r_fm = np.corrcoef(corrs_f, corrs_m)[0, 1]
print(f'Corrélation entre corr_F et corr_M : {r_fm:.4f}')
# Out:
# Corrélation entre corr_F et corr_M : 0.4648

# %% [markdown]
# ## 4. Réduction de Dimension (PCA, t-SNE, UMAP)
#
# On utilise les top-500 CpG les plus corrélés avec l'âge pour la visualisation.

# %%
# --- Charger les top-k CpG ---
print(f'Chargement des top {TOP_K} CpG pour réduction de dimension...')
t0 = time()
top_indices = np.argsort(np.abs(corrs_all))[::-1][:TOP_K]
indices_to_load = np.sort(top_indices)

rows = []
start = 0
for chunk in pd.read_csv(data_path, usecols=common_ids, chunksize=CHUNK_SIZE):
    end = start + len(chunk)
    pos_s = np.searchsorted(indices_to_load, start)
    pos_e = np.searchsorted(indices_to_load, end)
    local = indices_to_load[pos_s:pos_e] - start
    if len(local) > 0:
        rows.append(chunk.iloc[local].values)
    start = end

X_top = np.vstack(rows).T.astype(np.float32)  # (400, TOP_K)
print(f'  Chargé en {time()-t0:.1f}s, shape={X_top.shape}')
# Out:
# Chargement des top 500 CpG pour réduction de dimension...
#   Chargé en 14.5s, shape=(400, 500)

# %%
# --- PCA ---
pca = PCA(n_components=10, random_state=RANDOM_STATE)
X_pca = pca.fit_transform(X_top)

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# Variance expliquée
ax = axes[0]
ax.bar(range(1, 11), pca.explained_variance_ratio_ * 100, color='steelblue', alpha=0.8)
ax.plot(range(1, 11), np.cumsum(pca.explained_variance_ratio_) * 100, 'ro-', markersize=5)
ax.set_xlabel('Composante Principale')
ax.set_ylabel('Variance Expliquée (%)')
ax.set_title('PCA - Variance Expliquée')
ax.set_xticks(range(1, 11))

# PC1 vs PC2, coloré par âge
ax = axes[1]
sc = ax.scatter(X_pca[:, 0], X_pca[:, 1], c=ages, cmap='RdYlBu_r', s=30, alpha=0.7)
plt.colorbar(sc, ax=ax, label='Âge')
ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]*100:.1f}%)')
ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]*100:.1f}%)')
ax.set_title('PCA coloré par Âge')

# PC1 vs PC2, coloré par sexe
ax = axes[2]
for sexe, color, marker in [('F', '#e74c3c', 'o'), ('M', '#3498db', 's')]:
    mask = sexes == sexe
    ax.scatter(X_pca[mask, 0], X_pca[mask, 1], c=color, label=sexe,
               s=30, alpha=0.6, marker=marker)
ax.set_xlabel(f'PC1 ({pca.explained_variance_ratio_[0]*100:.1f}%)')
ax.set_ylabel(f'PC2 ({pca.explained_variance_ratio_[1]*100:.1f}%)')
ax.set_title('PCA coloré par Sexe')
ax.legend()

plt.tight_layout()
plt.savefig('results/eda_pca.png', dpi=150, bbox_inches='tight')
plt.show()

print(f'Variance cumulée (10 PC) : {np.sum(pca.explained_variance_ratio_)*100:.1f}%')
# Out:
# Variance cumulée (10 PC) : 75.0%

# %%
# --- t-SNE ---
print('t-SNE en cours...')
t0 = time()
tsne = TSNE(n_components=2, perplexity=30, random_state=RANDOM_STATE, max_iter=1000)
X_tsne = tsne.fit_transform(X_top)
print(f'  t-SNE terminé en {time()-t0:.1f}s')

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Coloré par âge
ax = axes[0]
sc = ax.scatter(X_tsne[:, 0], X_tsne[:, 1], c=ages, cmap='RdYlBu_r', s=30, alpha=0.7)
plt.colorbar(sc, ax=ax, label='Âge')
ax.set_xlabel('t-SNE 1')
ax.set_ylabel('t-SNE 2')
ax.set_title('t-SNE coloré par Âge')

# Coloré par sexe
ax = axes[1]
for sexe, color, marker in [('F', '#e74c3c', 'o'), ('M', '#3498db', 's')]:
    mask = sexes == sexe
    ax.scatter(X_tsne[mask, 0], X_tsne[mask, 1], c=color, label=sexe,
               s=30, alpha=0.6, marker=marker)
ax.set_xlabel('t-SNE 1')
ax.set_ylabel('t-SNE 2')
ax.set_title('t-SNE coloré par Sexe')
ax.legend()

plt.tight_layout()
plt.savefig('results/eda_tsne.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# t-SNE en cours...
#   t-SNE terminé en 0.5s

# %%
# --- UMAP ---
if HAS_UMAP:
    print('UMAP en cours...')
    t0 = time()
    reducer = umap.UMAP(n_components=2, n_neighbors=15, min_dist=0.1, random_state=RANDOM_STATE)
    X_umap = reducer.fit_transform(X_top)
    print(f'  UMAP terminé en {time()-t0:.1f}s')
    
    fig, axes = plt.subplots(1, 2, figsize=(14, 5))
    
    ax = axes[0]
    sc = ax.scatter(X_umap[:, 0], X_umap[:, 1], c=ages, cmap='RdYlBu_r', s=30, alpha=0.7)
    plt.colorbar(sc, ax=ax, label='Âge')
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')
    ax.set_title('UMAP coloré par Âge')
    
    ax = axes[1]
    for sexe, color, marker in [('F', '#e74c3c', 'o'), ('M', '#3498db', 's')]:
        mask = sexes == sexe
        ax.scatter(X_umap[mask, 0], X_umap[mask, 1], c=color, label=sexe,
                   s=30, alpha=0.6, marker=marker)
    ax.set_xlabel('UMAP 1')
    ax.set_ylabel('UMAP 2')
    ax.set_title('UMAP coloré par Sexe')
    ax.legend()
    
    plt.tight_layout()
    plt.savefig('results/eda_umap.png', dpi=150, bbox_inches='tight')
    plt.show()
else:
    print('UMAP non disponible. Installer avec : pip install umap-learn')
# Out:
# UMAP non disponible. Installer avec : pip install umap-learn

# %% [markdown]
# ## Résumé

# %%
print('=' * 60)
print('  RÉSUMÉ DE L\'ANALYSE EXPLORATOIRE')
print('=' * 60)
print(f'\n  Échantillons : {len(common_ids)}')
print(f'  CpG sites : {n_cpg}')
print(f'  Âge : {ages.mean():.1f} ± {ages.std():.1f} ({ages.min():.0f} - {ages.max():.0f})')
print(f'  Sexe : {(sexes=="F").sum()} F, {(sexes=="M").sum()} M')
print(f'\n  CpG fortement corrélés avec l\'âge :')
print(f'    |r| > 0.5 : {(np.abs(corrs_all) > 0.5).sum()}')
print(f'    |r| > 0.7 : {(np.abs(corrs_all) > 0.7).sum()}')
print(f'    |r| > 0.9 : {(np.abs(corrs_all) > 0.9).sum()}')
print(f'  Corrélation F-M : {r_fm:.4f}')
print(f'  PCA variance (10 PC) : {np.sum(pca.explained_variance_ratio_)*100:.1f}%')
print(f"\n{'='*60}")
# Out:
# ============================================================
#   RÉSUMÉ DE L'ANALYSE EXPLORATOIRE
# ============================================================
#
#   Échantillons : 400
#   CpG sites : 894006
#   Âge : 53.0 ± 21.2 (18 - 90)
#   Sexe : 214 F, 186 M
#
#   CpG fortement corrélés avec l'âge :
#     |r| > 0.5 : 4549
#     |r| > 0.7 : 233
#     |r| > 0.9 : 1
#   Corrélation F-M : 0.4648
#   PCA variance (10 PC) : 75.0%
#
# ============================================================

# %% [markdown]
# ---
#
# # Analyse Exploratoire en M-values
#
# Les M-values sont une transformation logit des B-values : $M = \log_2\left(\frac{\beta}{1 - \beta}\right)$
#
# Les M-values sont plus adaptées pour les analyses statistiques (distribution plus proche de la normale, variance plus homogène).
#
# On reprend les mêmes analyses que précédemment :
# 1. Moyenne et variance des M-values par âge et sexe
# 2. Comparaison des distributions B-values vs M-values
# 3. Corrélations M-values avec l'âge
# 4. Réduction de dimension (PCA, t-SNE) sur M-values

# %%
# --- Fonction de conversion B-value -> M-value ---
BETA_EPS = 1e-6

def beta_to_m(beta):
    """Convertit les B-values en M-values : M = log2(beta / (1 - beta))"""
    b = np.clip(beta, BETA_EPS, 1.0 - BETA_EPS)
    b = np.where(np.isnan(beta), np.nan, b)
    return np.log2(b / (1.0 - b))

print('Fonction beta_to_m définie.')
# Out:
# Fonction beta_to_m définie.

# %% [markdown]
# ## 5. Moyenne et Variance des M-values par Âge et Sexe

# %%
# --- Calculer mean/var des M-values par échantillon via chunks ---
print('Calcul des statistiques M-values par échantillon (par chunks)...')
t0 = time()
m_sample_sum = np.zeros(len(common_ids), dtype=np.float64)
m_sample_sum2 = np.zeros(len(common_ids), dtype=np.float64)
m_n_cpg = 0

for chunk in pd.read_csv(data_path, usecols=common_ids, chunksize=CHUNK_SIZE):
    x = chunk.to_numpy(dtype=np.float64)
    m = beta_to_m(x)
    m_sample_sum += np.nansum(m, axis=0)
    m_sample_sum2 += np.nansum(m**2, axis=0)
    m_n_cpg += len(chunk)

m_sample_mean = m_sample_sum / m_n_cpg
m_sample_var = m_sample_sum2 / m_n_cpg - m_sample_mean**2

print(f'  {m_n_cpg} CpG traités en {time()-t0:.1f}s')

# --- DataFrame de résultats M-values ---
m_stats_df = pd.DataFrame({
    'sample_id': common_ids,
    'mean_m': m_sample_mean,
    'var_m': m_sample_var,
    'age': ind.loc[common_ids, 'age'].values,
    'sexe': ind.loc[common_ids, 'sexe'].values,
    'age_group': ind.loc[common_ids, 'age_group'].values,
})

print(f'\nStatistiques M-values par groupe :')
print(m_stats_df.groupby('sexe')[['mean_m', 'var_m']].agg(['mean', 'std']).round(4))
print()
print(m_stats_df.groupby('age_group')[['mean_m', 'var_m']].agg(['mean', 'std']).round(4))
# Out:
# Calcul des statistiques M-values par échantillon (par chunks)...
#   894006 CpG traités en 16.3s
#
# Statistiques M-values par groupe :
#       mean_m            var_m
#         mean     std     mean     std
# sexe
# F     0.9828  0.0658  10.7525  0.5935
# M     0.9649  0.0977  10.9339  0.6329
#
#            mean_m            var_m
#              mean     std     mean     std
# age_group
# <30        1.0069  0.0748  10.9796  0.5403
# 30-50      0.9781  0.1083  10.7651  0.5842
# 50-70      0.9709  0.0540  10.7237  0.5103
# >70        0.9519  0.0726  10.9112  0.7531

# %%
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# --- Mean M vs Age, coloré par sexe ---
ax = axes[0, 0]
for sexe, color in [('F', '#e74c3c'), ('M', '#3498db')]:
    mask = m_stats_df['sexe'] == sexe
    ax.scatter(m_stats_df.loc[mask, 'age'], m_stats_df.loc[mask, 'mean_m'],
               alpha=0.6, label=sexe, color=color, s=30)
ax.set_xlabel('Âge')
ax.set_ylabel('Moyenne M-value (par échantillon)')
ax.set_title('Moyenne M-value vs Âge')
ax.legend()

# --- Variance M vs Age ---
ax = axes[0, 1]
for sexe, color in [('F', '#e74c3c'), ('M', '#3498db')]:
    mask = m_stats_df['sexe'] == sexe
    ax.scatter(m_stats_df.loc[mask, 'age'], m_stats_df.loc[mask, 'var_m'],
               alpha=0.6, label=sexe, color=color, s=30)
ax.set_xlabel('Âge')
ax.set_ylabel('Variance M-value (par échantillon)')
ax.set_title('Variance M-value vs Âge')
ax.legend()

# --- Boxplot mean M par age_group et sexe ---
ax = axes[1, 0]
sns.boxplot(data=m_stats_df, x='age_group', y='mean_m', hue='sexe',
            palette={'F': '#e74c3c', 'M': '#3498db'}, ax=ax)
ax.set_xlabel("Groupe d'âge")
ax.set_ylabel('Moyenne M-value')
ax.set_title("Moyenne M-value par groupe d'âge et sexe")

# --- Boxplot variance M par age_group et sexe ---
ax = axes[1, 1]
sns.boxplot(data=m_stats_df, x='age_group', y='var_m', hue='sexe',
            palette={'F': '#e74c3c', 'M': '#3498db'}, ax=ax)
ax.set_xlabel("Groupe d'âge")
ax.set_ylabel('Variance M-value')
ax.set_title("Variance M-value par groupe d'âge et sexe")

plt.tight_layout()
plt.savefig('results/eda_mean_var_m_values.png', dpi=150, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## 6. Comparaison des Distributions B-values vs M-values

# %%
# --- Convertir l'échantillon de 10K CpG déjà chargé en M-values ---
X_sample_m = beta_to_m(X_sample)  # (400, 10000)

fig, axes = plt.subplots(2, 3, figsize=(20, 10))

# --- Ligne 1 : B-values ---
ax = axes[0, 0]
ax.hist(X_sample.flatten(), bins=100, density=True, alpha=0.7, color='steelblue', edgecolor='none')
ax.set_xlabel('B-value')
ax.set_ylabel('Densité')
ax.set_title('Distribution globale B-values\n(10K CpG)')

ax = axes[0, 1]
for sexe, color in [('F', '#e74c3c'), ('M', '#3498db')]:
    mask = sexes == sexe
    means = X_sample[mask].mean(axis=1)
    ax.hist(means, bins=25, density=True, alpha=0.6, label=sexe, color=color, edgecolor='white')
ax.set_xlabel('Moyenne B-value par échantillon')
ax.set_ylabel('Densité')
ax.set_title('Moyenne B-value par sexe')
ax.legend()

ax = axes[0, 2]
data_violin_b = [X_sample[age_groups == ag].mean(axis=1) for ag in ['<30', '30-50', '50-70', '>70']]
parts = ax.violinplot(data_violin_b, positions=range(4), showmeans=True, showmedians=True)
ax.set_xticks(range(4))
ax.set_xticklabels(['<30', '30-50', '50-70', '>70'])
ax.set_xlabel("Groupe d'âge")
ax.set_ylabel('Moyenne B-value')
ax.set_title("B-values par groupe d'âge")

# --- Ligne 2 : M-values ---
ax = axes[1, 0]
ax.hist(X_sample_m.flatten(), bins=100, density=True, alpha=0.7, color='darkorange', edgecolor='none')
ax.set_xlabel('M-value')
ax.set_ylabel('Densité')
ax.set_title('Distribution globale M-values\n(10K CpG)')

ax = axes[1, 1]
for sexe, color in [('F', '#e74c3c'), ('M', '#3498db')]:
    mask = sexes == sexe
    means_m = np.nanmean(X_sample_m[mask], axis=1)
    ax.hist(means_m, bins=25, density=True, alpha=0.6, label=sexe, color=color, edgecolor='white')
ax.set_xlabel('Moyenne M-value par échantillon')
ax.set_ylabel('Densité')
ax.set_title('Moyenne M-value par sexe')
ax.legend()

ax = axes[1, 2]
data_violin_m = [np.nanmean(X_sample_m[age_groups == ag], axis=1) for ag in ['<30', '30-50', '50-70', '>70']]
parts = ax.violinplot(data_violin_m, positions=range(4), showmeans=True, showmedians=True)
ax.set_xticks(range(4))
ax.set_xticklabels(['<30', '30-50', '50-70', '>70'])
ax.set_xlabel("Groupe d'âge")
ax.set_ylabel('Moyenne M-value')
ax.set_title("M-values par groupe d'âge")

plt.tight_layout()
plt.savefig('results/eda_bvalues_vs_mvalues.png', dpi=150, bbox_inches='tight')
plt.show()

print(f'B-values range : [{np.nanmin(X_sample):.4f}, {np.nanmax(X_sample):.4f}]')
print(f'M-values range : [{np.nanmin(X_sample_m):.4f}, {np.nanmax(X_sample_m):.4f}]')
# Out:
# B-values range : [0.0029, 0.9949]
# M-values range : [-8.4444, 7.6095]

# %% [markdown]
# ## 7. Corrélations M-values avec l'Âge par Sexe

# %%
# --- Corrélations M-values avec l'âge (par chunks) ---
print('Calcul des corrélations M-value - âge par chunks...')
t0 = time()

m_corrs_all = []
m_corrs_f = []
m_corrs_m = []

for chunk in pd.read_csv(data_path, usecols=common_ids, chunksize=CHUNK_SIZE):
    x = chunk.to_numpy(dtype=np.float32)
    m = beta_to_m(x)
    # Remplir NaN par la moyenne par ligne pour le calcul de corrélation
    if np.isnan(m).any():
        row_means = np.nanmean(m, axis=1, keepdims=True)
        row_means = np.where(np.isnan(row_means), 0, row_means)
        m = np.where(np.isnan(m), row_means, m)
    
    # Global
    m_c = m - m.mean(axis=1, keepdims=True)
    num = m_c @ y_all_c
    den = np.sqrt(np.sum(m_c**2, axis=1)) * y_all_den
    m_corrs_all.append(np.divide(num, den, out=np.zeros_like(num), where=den != 0))
    
    # Femmes
    mf = m[:, mask_f]
    mf_c = mf - mf.mean(axis=1, keepdims=True)
    num_f = mf_c @ y_f_c
    den_f = np.sqrt(np.sum(mf_c**2, axis=1)) * y_f_den
    m_corrs_f.append(np.divide(num_f, den_f, out=np.zeros_like(num_f), where=den_f != 0))
    
    # Hommes
    mm = m[:, mask_m]
    mm_c = mm - mm.mean(axis=1, keepdims=True)
    num_m = mm_c @ y_m_c
    den_m = np.sqrt(np.sum(mm_c**2, axis=1)) * y_m_den
    m_corrs_m.append(np.divide(num_m, den_m, out=np.zeros_like(num_m), where=den_m != 0))

m_corrs_all = np.concatenate(m_corrs_all)
m_corrs_f = np.concatenate(m_corrs_f)
m_corrs_m = np.concatenate(m_corrs_m)

print(f'  Calculé en {time()-t0:.1f}s ({len(m_corrs_all)} CpG)')
print(f'  |corr| > 0.5 : {(np.abs(m_corrs_all) > 0.5).sum()} CpG')
print(f'  |corr| > 0.7 : {(np.abs(m_corrs_all) > 0.7).sum()} CpG')
print(f'  |corr| > 0.9 : {(np.abs(m_corrs_all) > 0.9).sum()} CpG')
# Out:
# Calcul des corrélations M-value - âge par chunks...
#   Calculé en 24.4s (894006 CpG)
#   |corr| > 0.5 : 4525 CpG
#   |corr| > 0.7 : 207 CpG
#   |corr| > 0.9 : 1 CpG

# %%
fig, axes = plt.subplots(2, 3, figsize=(20, 10))

# --- Ligne 1 : Corrélations B-values (rappel) ---
ax = axes[0, 0]
ax.hist(corrs_all, bins=200, density=True, alpha=0.7, color='steelblue', edgecolor='none')
ax.set_xlabel('Corrélation avec l\'âge')
ax.set_ylabel('Densité')
ax.set_title('B-values : corrélations CpG-âge')
ax.axvline(0, color='gray', linestyle='--', alpha=0.5)

ax = axes[0, 1]
ax.hist(corrs_f, bins=200, density=True, alpha=0.5, color='#e74c3c', label='Femmes', edgecolor='none')
ax.hist(corrs_m, bins=200, density=True, alpha=0.5, color='#3498db', label='Hommes', edgecolor='none')
ax.set_xlabel('Corrélation avec l\'âge')
ax.set_ylabel('Densité')
ax.set_title('B-values : corrélations par sexe')
ax.legend()

ax = axes[0, 2]
idx_sub = np.random.choice(len(corrs_all), size=min(50000, len(corrs_all)), replace=False)
ax.scatter(corrs_f[idx_sub], corrs_m[idx_sub], alpha=0.1, s=1, color='purple')
ax.plot([-1, 1], [-1, 1], 'r--', alpha=0.5)
ax.set_xlabel('Corrélation (Femmes)')
ax.set_ylabel('Corrélation (Hommes)')
ax.set_title('B-values : corr F vs M')
ax.set_xlim(-1, 1); ax.set_ylim(-1, 1); ax.set_aspect('equal')

# --- Ligne 2 : Corrélations M-values ---
ax = axes[1, 0]
ax.hist(m_corrs_all, bins=200, density=True, alpha=0.7, color='darkorange', edgecolor='none')
ax.set_xlabel('Corrélation avec l\'âge')
ax.set_ylabel('Densité')
ax.set_title('M-values : corrélations CpG-âge')
ax.axvline(0, color='gray', linestyle='--', alpha=0.5)

ax = axes[1, 1]
ax.hist(m_corrs_f, bins=200, density=True, alpha=0.5, color='#e74c3c', label='Femmes', edgecolor='none')
ax.hist(m_corrs_m, bins=200, density=True, alpha=0.5, color='#3498db', label='Hommes', edgecolor='none')
ax.set_xlabel('Corrélation avec l\'âge')
ax.set_ylabel('Densité')
ax.set_title('M-values : corrélations par sexe')
ax.legend()

ax = axes[1, 2]
idx_sub2 = np.random.choice(len(m_corrs_all), size=min(50000, len(m_corrs_all)), replace=False)
ax.scatter(m_corrs_f[idx_sub2], m_corrs_m[idx_sub2], alpha=0.1, s=1, color='darkorange')
ax.plot([-1, 1], [-1, 1], 'r--', alpha=0.5)
ax.set_xlabel('Corrélation (Femmes)')
ax.set_ylabel('Corrélation (Hommes)')
ax.set_title('M-values : corr F vs M')
ax.set_xlim(-1, 1); ax.set_ylim(-1, 1); ax.set_aspect('equal')

plt.tight_layout()
plt.savefig('results/eda_correlation_bvalues_vs_mvalues.png', dpi=150, bbox_inches='tight')
plt.show()

m_r_fm = np.corrcoef(m_corrs_f, m_corrs_m)[0, 1]
print(f'Corrélation entre corr_F et corr_M (B-values) : {r_fm:.4f}')
print(f'Corrélation entre corr_F et corr_M (M-values) : {m_r_fm:.4f}')

# Comparaison B vs M corrélations
bm_corr = np.corrcoef(corrs_all, m_corrs_all)[0, 1]
print(f'Corrélation entre corr_B et corr_M (globale) : {bm_corr:.4f}')
# Out:
# Corrélation entre corr_F et corr_M (B-values) : 0.4648
# Corrélation entre corr_F et corr_M (M-values) : 0.5274
# Corrélation entre corr_B et corr_M (globale) : 0.9731

# %% [markdown]
# ## 8. Réduction de Dimension sur M-values (PCA, t-SNE)
#
# On utilise les top-500 CpG les plus corrélés avec l'âge en M-values.

# %%
# --- Charger les top-k CpG en M-values ---
print(f'Chargement des top {TOP_K} CpG (M-values) pour réduction de dimension...')
t0 = time()
m_top_indices = np.argsort(np.abs(m_corrs_all))[::-1][:TOP_K]
m_indices_to_load = np.sort(m_top_indices)

rows_m = []
start = 0
for chunk in pd.read_csv(data_path, usecols=common_ids, chunksize=CHUNK_SIZE):
    end = start + len(chunk)
    pos_s = np.searchsorted(m_indices_to_load, start)
    pos_e = np.searchsorted(m_indices_to_load, end)
    local = m_indices_to_load[pos_s:pos_e] - start
    if len(local) > 0:
        vals = chunk.iloc[local].values
        rows_m.append(beta_to_m(vals))
    start = end

X_top_m = np.vstack(rows_m).T.astype(np.float32)  # (400, TOP_K)
# Remplir NaN restants par la moyenne de la colonne
col_means = np.nanmean(X_top_m, axis=0, keepdims=True)
X_top_m = np.where(np.isnan(X_top_m), col_means, X_top_m)

print(f'  Chargé en {time()-t0:.1f}s, shape={X_top_m.shape}')
# Out:
# Chargement des top 500 CpG (M-values) pour réduction de dimension...
#   Chargé en 14.5s, shape=(400, 500)

# %%
# --- PCA sur M-values ---
pca_m = PCA(n_components=10, random_state=RANDOM_STATE)
X_pca_m = pca_m.fit_transform(X_top_m)

fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# Variance expliquée
ax = axes[0]
ax.bar(range(1, 11), pca_m.explained_variance_ratio_ * 100, color='darkorange', alpha=0.8)
ax.plot(range(1, 11), np.cumsum(pca_m.explained_variance_ratio_) * 100, 'ro-', markersize=5)
ax.set_xlabel('Composante Principale')
ax.set_ylabel('Variance Expliquée (%)')
ax.set_title('PCA M-values - Variance Expliquée')
ax.set_xticks(range(1, 11))

# PC1 vs PC2, coloré par âge
ax = axes[1]
sc = ax.scatter(X_pca_m[:, 0], X_pca_m[:, 1], c=ages, cmap='RdYlBu_r', s=30, alpha=0.7)
plt.colorbar(sc, ax=ax, label='Âge')
ax.set_xlabel(f'PC1 ({pca_m.explained_variance_ratio_[0]*100:.1f}%)')
ax.set_ylabel(f'PC2 ({pca_m.explained_variance_ratio_[1]*100:.1f}%)')
ax.set_title('PCA M-values coloré par Âge')

# PC1 vs PC2, coloré par sexe
ax = axes[2]
for sexe, color, marker in [('F', '#e74c3c', 'o'), ('M', '#3498db', 's')]:
    mask = sexes == sexe
    ax.scatter(X_pca_m[mask, 0], X_pca_m[mask, 1], c=color, label=sexe,
               s=30, alpha=0.6, marker=marker)
ax.set_xlabel(f'PC1 ({pca_m.explained_variance_ratio_[0]*100:.1f}%)')
ax.set_ylabel(f'PC2 ({pca_m.explained_variance_ratio_[1]*100:.1f}%)')
ax.set_title('PCA M-values coloré par Sexe')
ax.legend()

plt.tight_layout()
plt.savefig('results/eda_pca_mvalues.png', dpi=150, bbox_inches='tight')
plt.show()

print(f'Variance cumulée B-values (10 PC) : {np.sum(pca.explained_variance_ratio_)*100:.1f}%')
print(f'Variance cumulée M-values (10 PC) : {np.sum(pca_m.explained_variance_ratio_)*100:.1f}%')
# Out:
# Variance cumulée B-values (10 PC) : 75.0%
# Variance cumulée M-values (10 PC) : 75.4%

# %%
# --- t-SNE sur M-values ---
print('t-SNE M-values en cours...')
t0 = time()
tsne_m = TSNE(n_components=2, perplexity=30, random_state=RANDOM_STATE, max_iter=1000)
X_tsne_m = tsne_m.fit_transform(X_top_m)
print(f'  t-SNE terminé en {time()-t0:.1f}s')

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Coloré par âge
ax = axes[0]
sc = ax.scatter(X_tsne_m[:, 0], X_tsne_m[:, 1], c=ages, cmap='RdYlBu_r', s=30, alpha=0.7)
plt.colorbar(sc, ax=ax, label='Âge')
ax.set_xlabel('t-SNE 1')
ax.set_ylabel('t-SNE 2')
ax.set_title('t-SNE M-values coloré par Âge')

# Coloré par sexe
ax = axes[1]
for sexe, color, marker in [('F', '#e74c3c', 'o'), ('M', '#3498db', 's')]:
    mask = sexes == sexe
    ax.scatter(X_tsne_m[mask, 0], X_tsne_m[mask, 1], c=color, label=sexe,
               s=30, alpha=0.6, marker=marker)
ax.set_xlabel('t-SNE 1')
ax.set_ylabel('t-SNE 2')
ax.set_title('t-SNE M-values coloré par Sexe')
ax.legend()

plt.tight_layout()
plt.savefig('results/eda_tsne_mvalues.png', dpi=150, bbox_inches='tight')
plt.show()
# Out:
# t-SNE M-values en cours...
#   t-SNE terminé en 0.5s

# %% [markdown]
# ## Résumé Comparatif B-values vs M-values

# %%
print('=' * 60)
print('  RÉSUMÉ COMPARATIF B-values vs M-values')
print('=' * 60)

print(f'\n  {"Métrique":<40} {"B-values":>10} {"M-values":>10}')
print(f'  {"-"*60}')
print(f'  {"CpG |corr| > 0.5":<40} {(np.abs(corrs_all) > 0.5).sum():>10} {(np.abs(m_corrs_all) > 0.5).sum():>10}')
print(f'  {"CpG |corr| > 0.7":<40} {(np.abs(corrs_all) > 0.7).sum():>10} {(np.abs(m_corrs_all) > 0.7).sum():>10}')
print(f'  {"CpG |corr| > 0.9":<40} {(np.abs(corrs_all) > 0.9).sum():>10} {(np.abs(m_corrs_all) > 0.9).sum():>10}')
print(f'  {"Corr F-M":<40} {r_fm:>10.4f} {m_r_fm:>10.4f}')
print(f'  {"PCA variance (10 PC)":<40} {np.sum(pca.explained_variance_ratio_)*100:>9.1f}% {np.sum(pca_m.explained_variance_ratio_)*100:>9.1f}%')
print(f'  {"Corr entre corr_B et corr_M":<40} {bm_corr:>10.4f}')
print(f'\n{"="*60}')
# Out:
# ============================================================
#   RÉSUMÉ COMPARATIF B-values vs M-values
# ============================================================
#
#   Métrique                                   B-values   M-values
#   ------------------------------------------------------------
#   CpG |corr| > 0.5                               4549       4525
#   CpG |corr| > 0.7                                233        207
#   CpG |corr| > 0.9                                  1          1
#   Corr F-M                                     0.4648     0.5274
#   PCA variance (10 PC)                          75.0%      75.4%
#   Corr entre corr_B et corr_M                  0.9731
#
# ============================================================
